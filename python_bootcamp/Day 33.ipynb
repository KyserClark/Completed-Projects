# %% [markdown]
# # Day 32

# %%
import requests

# %%
import bs4

# %%
result = requests.get("https://www.kyserclark.com")

# %%
type(result)
# Out:
# requests.models.Response

# %%
result.text
# Out:
# '<!DOCTYPE html>\n<html lang="en">\n<head>\n  \n  <meta charset=\'utf-8\'>\n  <meta name="viewport" content="width=device-width, initial-scale=1" id="wixDesktopViewport" />\n  <meta http-equiv="X-UA-Compatible" content="IE=edge">\n  <meta name="generator" content="Wix.com Website Builder"/>\n\n  <link rel="icon" sizes="192x192" href="https://static.wixstatic.com/media/f9d248_759a134c71864e9b875cd85d51202aa0%7Emv2.png/v1/fill/w_32%2Ch_32%2Clg_1%2Cusm_0.66_1.00_0.01/f9d248_759a134c71864e9b875cd85d51202aa0%7Emv2.png">\n  <link rel="shortcut icon" href="https://static.wixstatic.com/media/f9d248_759a134c71864e9b875cd85d51202aa0%7Emv2.png/v1/fill/w_32%2Ch_32%2Clg_1%2Cusm_0.66_1.00_0.01/f9d248_759a134c71864e9b875cd85d51202aa0%7Emv2.png" type="image/png"/>\n  <link rel="apple-touch-icon" href="https://static.wixstatic.com/media/f9d248_759a134c71864e9b875cd85d51202aa0%7Emv2.png/v1/fill/w_32%2Ch_32%2Clg_1%2Cusm_0.66_1.00_0.01/f9d248_759a134c71864e9b875cd85d51202aa0%7Emv2.png" type="image/png"/
# ...

# %%
soup = bs4.BeautifulSoup(result.text,'lxml')

# %%
soup
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1" id="wixDesktopViewport" name="viewport"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="Wix.com Website Builder" name="generator"/>
# <link href="https://static.wixstatic.com/media/f9d248_759a134c71864e9b875cd85d51202aa0%7Emv2.png/v1/fill/w_32%2Ch_32%2Clg_1%2Cusm_0.66_1.00_0.01/f9d248_759a134c71864e9b875cd85d51202aa0%7Emv2.png" rel="icon" sizes="192x192"/>
# <link href="https://static.wixstatic.com/media/f9d248_759a134c71864e9b875cd85d51202aa0%7Emv2.png/v1/fill/w_32%2Ch_32%2Clg_1%2Cusm_0.66_1.00_0.01/f9d248_759a134c71864e9b875cd85d51202aa0%7Emv2.png" rel="shortcut icon" type="image/png"/>
# <link href="https://static.wixstatic.com/media/f9d248_759a134c71864e9b875cd85d51202aa0%7Emv2.png/v1/fill/w_32%2Ch_32%2Clg_1%2Cusm_0.66_1.00_0.01/f9d248_759a134c71864e9b875cd85d51202aa0%7Emv2.png" rel="apple-touch-icon" type="image/png"/>
# ...

# %%
soup.select('title')
# Out:
# [<title>Kyser Clark - Cybersecurity</title>]

# %%
soup.select('p')
# Out:
# [<p class="k7nuw" id="comp-ioclk9190label" style="text-align:right">Main</p>,
#  <p class="k7nuw" id="comp-ioclk9191label" style="text-align:right">Videos</p>,
#  <p class="k7nuw" id="comp-ioclk9192label" style="text-align:right">Blog</p>,
#  <p class="k7nuw" id="comp-ioclk9193label" style="text-align:right">Résumé</p>,
#  <p class="k7nuw" id="comp-ioclk9194label" style="text-align:right">About</p>,
#  <p class="k7nuw" id="comp-ioclk9195label" style="text-align:right">Connect</p>,
#  <p class="k7nuw" id="comp-ioclk919__more__label" style="text-align:right">More...</p>]

# %%
soup.select('head')
# Out:
# [<head>
#  <meta charset="utf-8"/>
#  <meta content="width=device-width, initial-scale=1" id="wixDesktopViewport" name="viewport"/>
#  <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#  <meta content="Wix.com Website Builder" name="generator"/>
#  <link href="https://static.wixstatic.com/media/f9d248_759a134c71864e9b875cd85d51202aa0%7Emv2.png/v1/fill/w_32%2Ch_32%2Clg_1%2Cusm_0.66_1.00_0.01/f9d248_759a134c71864e9b875cd85d51202aa0%7Emv2.png" rel="icon" sizes="192x192"/>
#  <link href="https://static.wixstatic.com/media/f9d248_759a134c71864e9b875cd85d51202aa0%7Emv2.png/v1/fill/w_32%2Ch_32%2Clg_1%2Cusm_0.66_1.00_0.01/f9d248_759a134c71864e9b875cd85d51202aa0%7Emv2.png" rel="shortcut icon" type="image/png"/>
#  <link href="https://static.wixstatic.com/media/f9d248_759a134c71864e9b875cd85d51202aa0%7Emv2.png/v1/fill/w_32%2Ch_32%2Clg_1%2Cusm_0.66_1.00_0.01/f9d248_759a134c71864e9b875cd85d51202aa0%7Emv2.png" rel="apple-touch-icon" type="image/png"/>
#  <!-- Safari Pinned Tab Icon -->
# ...

# %%
soup.select('title')[0]
# Out:
# <title>Kyser Clark - Cybersecurity</title>

# %%
soup.select('title')[0].getText()
# Out:
# 'Kyser Clark - Cybersecurity'

# %%
site_paragraphs = soup.select('p')

# %%
site_paragraphs
# Out:
# [<p class="k7nuw" id="comp-ioclk9190label" style="text-align:right">Main</p>,
#  <p class="k7nuw" id="comp-ioclk9191label" style="text-align:right">Videos</p>,
#  <p class="k7nuw" id="comp-ioclk9192label" style="text-align:right">Blog</p>,
#  <p class="k7nuw" id="comp-ioclk9193label" style="text-align:right">Résumé</p>,
#  <p class="k7nuw" id="comp-ioclk9194label" style="text-align:right">About</p>,
#  <p class="k7nuw" id="comp-ioclk9195label" style="text-align:right">Connect</p>,
#  <p class="k7nuw" id="comp-ioclk919__more__label" style="text-align:right">More...</p>]

# %%
site_paragraphs[0]
# Out:
# <p class="k7nuw" id="comp-ioclk9190label" style="text-align:right">Main</p>

# %%
type(site_paragraphs[0])
# Out:
# bs4.element.Tag

# %%
site_paragraphs[0].getText()
# Out:
# 'Main'

# %% [markdown]
# # Day 33

# %%
res = requests.get('https://en.wikipedia.org/wiki/List_of_Mortal_Kombat_characters')

# %%
soup = bs4.BeautifulSoup(res.text,'lxml')

# %%
soup
# Out:
# <!DOCTYPE html>
# <html class="client-nojs" dir="ltr" lang="en">
# <head>
# <meta charset="utf-8"/>
# <title>List of Mortal Kombat characters - Wikipedia</title>
# ...

# %%
soup.select('.toctext')
# Out:
# [<span class="toctext">Introduced in <i>Mortal Kombat</i> (1992)</span>,
#  <span class="toctext">Johnny Cage</span>,
#  <span class="toctext">Kano</span>,
#  <span class="toctext">Liu Kang</span>,
#  <span class="toctext">Raiden</span>,
#  <span class="toctext">Scorpion</span>,
#  <span class="toctext">Sonya Blade</span>,
#  <span class="toctext">Sub-Zero</span>,
#  <span class="toctext">Goro</span>,
#  <span class="toctext">Shang Tsung</span>,
#  <span class="toctext">Reptile</span>,
#  <span class="toctext">Introduced in <i>Mortal Kombat II</i></span>,
#  <span class="toctext">Baraka</span>,
#  <span class="toctext">Jade</span>,
#  <span class="toctext">Jax</span>,
#  <span class="toctext">Kintaro</span>,
#  <span class="toctext">Kitana</span>,
#  <span class="toctext">Kung Lao</span>,
#  <span class="toctext">Mileena</span>,
#  <span class="toctext">Noob Saibot</span>,
#  <span class="toctext">Shao Kahn</span>,
#  <span class="toctext">Smoke</span>,
# ...

# %%
type(soup.select('.toctext')[0])
# Out:
# bs4.element.Tag

# %%
first_item = soup.select('.toctext')[0]

# %%
first_item
# Out:
# <span class="toctext">Introduced in <i>Mortal Kombat</i> (1992)</span>

# %%
first_item.text
# Out:
# 'Introduced in Mortal Kombat (1992)'

# %%
for item in soup.select('.toctext'):
    print(item.text)
# Out:
# Introduced in Mortal Kombat (1992)
# Johnny Cage
# Kano
# Liu Kang
# Raiden
# Scorpion
# Sonya Blade
# Sub-Zero
# Goro
# Shang Tsung
# Reptile
# Introduced in Mortal Kombat II
# Baraka
# Jade
# Jax
# Kintaro
# Kitana
# Kung Lao
# Mileena
# Noob Saibot
# Shao Kahn
# Smoke
# Introduced in Mortal Kombat 3 and updates
# Chameleon
# Cyrax
# Ermac
# Kabal
# Khameleon
# Motaro
# Nightwolf
# Rain
# Sektor
# Sheeva
# Sindel
# Stryker
# Introduced in Mortal Kombat Mythologies: Sub-Zero
# Fujin
# Quan Chi
# Sareena
# Shinnok
# Introduced in Mortal Kombat 4
# Jarek
# Kai
# Meat
# Reiko
# Tanya
# Introduced in Mortal Kombat: Special Forces
# Tremor
# Introduced in Mortal Kombat: Deadly Alliance
# Blaze
# Bo' Rai Cho
# Drahmin
# Frost
# Hsu Hao
# Kenshi
# Li Mei
# Mavado
# Mokap
# Moloch
# Nitara
# Introduced in Mortal Kombat: Deception
# Ashrah
# Dairou
# Darrius
# Havik
# Hotaru
# Kira
# Kobra
# Onaga
# Shujinko
# Introduced in Mortal Kombat: Armageddon
# Daegon
# Taven
# ...

# %%
res = requests.get("https://en.wikipedia.org/wiki/Mortal_Kombat")

# %%
soup = bs4.BeautifulSoup(res.text,'lxml')

# %%
soup
# Out:
# <!DOCTYPE html>
# <html class="client-nojs" dir="ltr" lang="en">
# <head>
# <meta charset="utf-8"/>
# <title>Mortal Kombat - Wikipedia</title>
# ...

# %%
soup.select('img')
# Out:
# [<img alt="This is a good article. Click here for more information." data-file-height="185" data-file-width="180" decoding="async" height="20" src="//upload.wikimedia.org/wikipedia/en/thumb/9/94/Symbol_support_vote.svg/19px-Symbol_support_vote.svg.png" srcset="//upload.wikimedia.org/wikipedia/en/thumb/9/94/Symbol_support_vote.svg/29px-Symbol_support_vote.svg.png 1.5x, //upload.wikimedia.org/wikipedia/en/thumb/9/94/Symbol_support_vote.svg/39px-Symbol_support_vote.svg.png 2x" width="19"/>,
#  <img alt="Mortal Kombat Logo.svg" data-file-height="300" data-file-width="300" decoding="async" height="250" src="//upload.wikimedia.org/wikipedia/en/thumb/b/b1/Mortal_Kombat_Logo.svg/250px-Mortal_Kombat_Logo.svg.png" srcset="//upload.wikimedia.org/wikipedia/en/thumb/b/b1/Mortal_Kombat_Logo.svg/375px-Mortal_Kombat_Logo.svg.png 1.5x, //upload.wikimedia.org/wikipedia/en/thumb/b/b1/Mortal_Kombat_Logo.svg/500px-Mortal_Kombat_Logo.svg.png 2x" width="250"/>,
# ...

# %%
soup.select('img')[0]
# Out:
# <img alt="This is a good article. Click here for more information." data-file-height="185" data-file-width="180" decoding="async" height="20" src="//upload.wikimedia.org/wikipedia/en/thumb/9/94/Symbol_support_vote.svg/19px-Symbol_support_vote.svg.png" srcset="//upload.wikimedia.org/wikipedia/en/thumb/9/94/Symbol_support_vote.svg/29px-Symbol_support_vote.svg.png 1.5x, //upload.wikimedia.org/wikipedia/en/thumb/9/94/Symbol_support_vote.svg/39px-Symbol_support_vote.svg.png 2x" width="19"/>

# %%
soup.select('.image')
# Out:
# [<a class="image" href="/wiki/File:Mortal_Kombat_Logo.svg"><img alt="Mortal Kombat Logo.svg" data-file-height="300" data-file-width="300" decoding="async" height="250" src="//upload.wikimedia.org/wikipedia/en/thumb/b/b1/Mortal_Kombat_Logo.svg/250px-Mortal_Kombat_Logo.svg.png" srcset="//upload.wikimedia.org/wikipedia/en/thumb/b/b1/Mortal_Kombat_Logo.svg/375px-Mortal_Kombat_Logo.svg.png 1.5x, //upload.wikimedia.org/wikipedia/en/thumb/b/b1/Mortal_Kombat_Logo.svg/500px-Mortal_Kombat_Logo.svg.png 2x" width="250"/></a>,
# ...

# %%
mklogo = soup.select('.thumbimage')[0]

# %%
mklogo
# Out:
# <img alt="" class="thumbimage" data-file-height="640" data-file-width="640" decoding="async" height="170" src="//upload.wikimedia.org/wikipedia/commons/thumb/9/97/Mortal_Kombat_II_arcade_cabinet.jpg/170px-Mortal_Kombat_II_arcade_cabinet.jpg" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/9/97/Mortal_Kombat_II_arcade_cabinet.jpg/255px-Mortal_Kombat_II_arcade_cabinet.jpg 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/9/97/Mortal_Kombat_II_arcade_cabinet.jpg/340px-Mortal_Kombat_II_arcade_cabinet.jpg 2x" width="170"/>

# %%
mklogo['src']
# Out:
# '//upload.wikimedia.org/wikipedia/commons/thumb/9/97/Mortal_Kombat_II_arcade_cabinet.jpg/170px-Mortal_Kombat_II_arcade_cabinet.jpg'

# %% [markdown]
# <img
# src='//upload.wikimedia.org/wikipedia/commons/thumb/9/97/Mortal_Kombat_II_arcade_cabinet.jpg/170px-Mortal_Kombat_II_arcade_cabinet.jpg'>

# %%
image_link = requests.get('https://upload.wikimedia.org/wikipedia/commons/thumb/9/97/Mortal_Kombat_II_arcade_cabinet.jpg/170px-Mortal_Kombat_II_arcade_cabinet.jpg')

# %%
image_link.content
# Out:
# b'\xff\xd8\xff\xdb\x00C\x00\x04\x03\x03\x04\x03\x03\x04\x04\x03\x04\x05\x04\x04\x05\x06\n\x07\x06\x06\x06\x06\r\t\n\x08\n\x0f\r\x10\x10\x0f\r\x0f\x0e\x11\x13\x18\x14\x11\x12\x17\x12\x0e\x0f\x15\x1c\x15\x17\x19\x19\x1b\x1b\x1b\x10\x14\x1d\x1f\x1d\x1a\x1f\x18\x1a\x1b\x1a\xff\xdb\x00C"\x00\x02\x11\x01\x03\x11\x01\xff\xc4\x00\x1d\x00\x00\x02\x03\x01\x01\x01\x01\x01\x00\x00\x00\x00\x00\x00\x00\x00\x06\x07\x04\x05\x08\x03\x02\x01\t\x00\xff\xc4\x00?\x10\x00\x01\x03\x03\x03\x02\x05\x02\x03\x05\x07\x03\x04\x03\x00\x00\x01\x02\x03\x04\x05\x06\x11\x00\x12!\x071\x13"AQa\x14q\x082\x81\x15#R\x91\xa1\x163Bbr\x82\xb1C\xc1\xd1\x17\x92\xa2\xe1$4\xf0\xff\xc4\x00\x1c\x01\x00\x03\x00\x03\x01\x01\x01\x00\x0
# ...

# %%
mk_arcade = open('mk arcade.jpg','wb')

# %%
mk_arcade.write(image_link.content)
# Out:
# 15812

# %%
mk_arcade.close()

# %%
# Goal: Get Title of every book that has two star rating

# %%
'https://books.toscrape.com/catalogue/page-2.html'
# Out:
# 'https://books.toscrape.com/catalogue/page-2.html'

# %%
base_url = 'https://books.toscrape.com/catalogue/page-{}.html'

# %%
base_url.format(10)
# Out:
# 'https://books.toscrape.com/catalogue/page-10.html'

# %%
page_num = 1
base_url.format(page_num)
# Out:
# 'https://books.toscrape.com/catalogue/page-12.html'

# %%
res = requests.get(base_url.format(1))

# %%
soup = bs4.BeautifulSoup(res.text,'lxml')

# %%
soup.select('.product_pod')
# Out:
# [<article class="product_pod">
#  <div class="image_container">
#  <a href="a-light-in-the-attic_1000/index.html"><img alt="A Light in the Attic" class="thumbnail" src="../media/cache/2c/da/2cdad67c44b002e7ead0cc35693c0e8b.jpg"/></a>
#  </div>
#  <p class="star-rating Three">
#  <i class="icon-star"></i>
#  <i class="icon-star"></i>
#  <i class="icon-star"></i>
#  <i class="icon-star"></i>
#  <i class="icon-star"></i>
#  </p>
#  <h3><a href="a-light-in-the-attic_1000/index.html" title="A Light in the Attic">A Light in the ...</a></h3>
#  <div class="product_price">
#  <p class="price_color">Â£51.77</p>
#  <p class="instock availability">
#  <i class="icon-ok"></i>
#
#          In stock
#
#  </p>
#  <form>
#  <button class="btn btn-primary btn-block" data-loading-text="Adding..." type="submit">Add to basket</button>
#  </form>
#  </div>
#  </article>,
#  <article class="product_pod">
#  <div class="image_container">
# ...

# %%
len(soup.select('.product_pod'))
# Out:
# 20

# %%
products = soup.select('.product_pod')

# %%
example = products[0]

# %%
example
# Out:
# <article class="product_pod">
# <div class="image_container">
# <a href="a-light-in-the-attic_1000/index.html"><img alt="A Light in the Attic" class="thumbnail" src="../media/cache/2c/da/2cdad67c44b002e7ead0cc35693c0e8b.jpg"/></a>
# </div>
# <p class="star-rating Three">
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# </p>
# <h3><a href="a-light-in-the-attic_1000/index.html" title="A Light in the Attic">A Light in the ...</a></h3>
# <div class="product_price">
# <p class="price_color">Â£51.77</p>
# <p class="instock availability">
# <i class="icon-ok"></i>
#
#         In stock
#
# </p>
# <form>
# <button class="btn btn-primary btn-block" data-loading-text="Adding..." type="submit">Add to basket</button>
# </form>
# </div>
# </article>

# %%
str(example)
# Out:
# '<article class="product_pod">\n<div class="image_container">\n<a href="a-light-in-the-attic_1000/index.html"><img alt="A Light in the Attic" class="thumbnail" src="../media/cache/2c/da/2cdad67c44b002e7ead0cc35693c0e8b.jpg"/></a>\n</div>\n<p class="star-rating Three">\n<i class="icon-star"></i>\n<i class="icon-star"></i>\n<i class="icon-star"></i>\n<i class="icon-star"></i>\n<i class="icon-star"></i>\n</p>\n<h3><a href="a-light-in-the-attic_1000/index.html" title="A Light in the Attic">A Light in the ...</a></h3>\n<div class="product_price">\n<p class="price_color">Â£51.77</p>\n<p class="instock availability">\n<i class="icon-ok"></i>\n    \n        In stock\n    \n</p>\n<form>\n<button class="btn btn-primary btn-block" data-loading-text="Adding..." type="submit">Add to basket</button>\n</form>\n</div>\n</article>'

# %%
'star-rating Three' in str(example)
# Out:
# True

# %%
example.select('.star-rating.Three')
# Out:
# [<p class="star-rating Three">
#  <i class="icon-star"></i>
#  <i class="icon-star"></i>
#  <i class="icon-star"></i>
#  <i class="icon-star"></i>
#  <i class="icon-star"></i>
#  </p>]

# %%
example.select('.star-rating.Two')
# Out:
# []

# %%
[] == example.select('.star-rating.Two')
# Out:
# True

# %%
example.select('a')
# Out:
# [<a href="a-light-in-the-attic_1000/index.html"><img alt="A Light in the Attic" class="thumbnail" src="../media/cache/2c/da/2cdad67c44b002e7ead0cc35693c0e8b.jpg"/></a>,
#  <a href="a-light-in-the-attic_1000/index.html" title="A Light in the Attic">A Light in the ...</a>]

# %%
example.select('a')[1]
# Out:
# <a href="a-light-in-the-attic_1000/index.html" title="A Light in the Attic">A Light in the ...</a>

# %%
type(example.select('a')[1])
# Out:
# bs4.element.Tag

# %%
example.select('a')[1]['title']
# Out:
# 'A Light in the Attic'

# %%
# We can check if something is 2 stars (string call in, example.select(rating))
# example.select('a')[1]['title'] to grab the book title

# %%
two_star_titles = []

for n in range(1,51):
    
    scrape_url = base_url.format(n)
    res = requests.get(scrape_url)
    
    soup = bs4.BeautifulSoup(res.text,'lxml')
    books = soup.select(".product_pod")
    
    for book in books:
        if len(book.select('.star-rating.Two')) != 0:
            book_title = book.select('a')[1]['title']
            two_star_titles.append(book_title)

# %%
two_star_titles
# Out:
# ['Starving Hearts (Triangular Trade Trilogy, #1)',
#  'Libertarianism for Beginners',
#  "It's Only the Himalayas",
#  'How Music Works',
#  'Maude (1883-1993):She Grew Up with the country',
#  "You can't bury them all: Poems",
#  'Reasons to Stay Alive',
#  'Without Borders (Wanderlove #1)',
#  'Soul Reader',
#  'Security',
#  'Saga, Volume 5 (Saga (Collected Editions) #5)',
#  'Reskilling America: Learning to Labor in the Twenty-First Century',
#  'Political Suicide: Missteps, Peccadilloes, Bad Calls, Backroom Hijinx, Sordid Pasts, Rotten Breaks, and Just Plain Dumb Mistakes in the Annals of American Politics',
#  'Obsidian (Lux #1)',
#  'My Paris Kitchen: Recipes and Stories',
#  'Masks and Shadows',
#  'Lumberjanes, Vol. 2: Friendship to the Max (Lumberjanes #5-8)',
#  'Lumberjanes Vol. 3: A Terrible Plan (Lumberjanes #9-12)',
#  'Judo: Seven Steps to Black Belt (an Introductory Guide for Beginners)',
# ...
